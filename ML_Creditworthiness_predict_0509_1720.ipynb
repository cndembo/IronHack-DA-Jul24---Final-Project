# %% [markdown]
# ### Final Project - Credit Lend Prediction

# %%
#Libraries
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import LabelEncoder

from sklearn.preprocessing import MinMaxScaler, StandardScaler
#from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score

# %%
#Load data
bank_df = pd.read_csv('bank_df_cleaned.csv')

# %%
#Analyse the data
display(bank_df.head())
display(bank_df.shape)
bank_df.dtypes
# Out:
#    Unnamed: 0      ID Customer_ID  Month           Name  Age  Annual_Income  \
# 0           0  0x1602   CUS_0xd40      1  Aaron Maashoh   23       19114.12
# 1           1  0x1603   CUS_0xd40      2  Aaron Maashoh   23       19114.12
# 2           2  0x1604   CUS_0xd40      3  Aaron Maashoh   23       19114.12
# 3           3  0x1605   CUS_0xd40      4  Aaron Maashoh   23       19114.12
# 4           4  0x1606   CUS_0xd40      5  Aaron Maashoh   23       19114.12
#
#    Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  ...  \
# 0            1824.843333                  3                4  ...
# 1            1824.843333                  3                4  ...
# 2            1824.843333                  3                4  ...
# 3            1824.843333                  3                4  ...
# 4            1824.843333                  3                4  ...
#
#    Num_of_Delayed_Payment  Credit_Mix Credit_Utilization_Ratio  \
# 0                       7    Standard                     27.0
# 1                       0        Good                     32.0
# 2                       7        Good                     29.0
# 3                       4        Good                     31.0
# 4                       0        Good                     25.0
#
#    Payment_of_Min_Amount                 Payment_Behaviour Monthly_Balance  \
# 0                     No   High_spent_Small_value_payments         312.494
# 1                     No    Low_spent_Large_value_payments         284.629
# 2                     No   Low_spent_Medium_value_payments         331.210
# 3                     No    Low_spent_Small_value_payments         223.451
# 4                     No  High_spent_Medium_value_payments         341.489
#
#    Credit_Score Years Months  Type_of_Loan_fixed
# 0          Good    22      1               Mixed
# 1          Good    22      1               Mixed
# 2          Good    22      3               Mixed
# 3          Good    22      4               Mixed
# 4          Good    22      5               Mixed
#
# [5 rows x 24 columns]
# (99992, 24)
# Unnamed: 0                    int64
# ID                           object
# Customer_ID                  object
# Month                         int64
# Name                         object
# Age                           int64
# Annual_Income               float64
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                   int64
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment        int64
# Credit_Mix                   object
# Credit_Utilization_Ratio    float64
# Payment_of_Min_Amount        object
# Payment_Behaviour            object
# Monthly_Balance             float64
# Credit_Score                 object
# Years                         int64
# Months                        int64
# Type_of_Loan_fixed           object
# dtype: object

# %% [markdown]
# ## Select features

# %%
bank_df = pd.read_csv('bank_df_cleaned.csv')

#Label encoding
bank_df['Credit_Mix'] = bank_df['Credit_Mix'].astype(str)

label_encoder = LabelEncoder()
bank_df['Payment_Amount_encoded'] = label_encoder.fit_transform(bank_df['Payment_of_Min_Amount'])
# Type_of_Loan_fixed_encoded - One-hot enconding
bank_df['Type_of_Loan_fixed_encoded'] = label_encoder.fit_transform(bank_df['Type_of_Loan_fixed'])

# %%
#manual Label encoding

credit_mix_mapping = {'Bad': 0, 'Standard': 1, 'Good': 2}
credit_score_mapping = {'Poor': 0, 'Standard': 1, 'Good': 2}
payment_behaviour_mapping = {'Low_spent_Small_value_payments':0,
                             'Low_spent_Medium_value_payments':1,
                            'Low_spent_Large_value_payments':2,
                            'High_spent_Small_value_payments':3,
                            'High_spent_Medium_value_payments':4,
                            'High_spent_Large_value_payments':5}


# Apply the mappings
bank_df['Credit_Mix_encoded'] = bank_df['Credit_Mix'].map(credit_mix_mapping)
bank_df['Credit_Score_encoded'] = bank_df['Credit_Score'].map(credit_score_mapping)
bank_df['Payment_Behaviour_encoded'] = bank_df['Payment_Behaviour'].map(payment_behaviour_mapping)

# %%
#distinguish target and features data frames

#target = ['Safe','Unsafe']
target = bank_df['Credit_Score_encoded']

features = bank_df.drop(columns = ['ID','Age','Customer_ID', 'Name', 'Type_of_Loan', 'Month', 'Months', 'Years', 'Credit_Mix', 'Payment_of_Min_Amount', 'Payment_Behaviour', 'Credit_Score', 'Type_of_Loan_fixed', 'Credit_Score_encoded'])

# %%
features.dtypes
# Out:
# Unnamed: 0                      int64
# Annual_Income                 float64
# Monthly_Inhand_Salary         float64
# Num_Bank_Accounts               int64
# Num_Credit_Card                 int64
# Interest_Rate                   int64
# Num_of_Loan                     int64
# Delay_from_due_date             int64
# Num_of_Delayed_Payment          int64
# Credit_Utilization_Ratio      float64
# Monthly_Balance               float64
# Payment_Amount_encoded          int32
# Type_of_Loan_fixed_encoded      int32
# Credit_Mix_encoded              int64
# Payment_Behaviour_encoded       int64
# dtype: object

# %%
#no features engeneering to apply
#split train/test
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.25, random_state = 0)

# %%
#apply feature scalling
#normalizer = MinMaxScaler()
standerdizer = StandardScaler()
#normalizer.fit(X_train)

# %%
#Initialize Classification models
rfc = RandomForestClassifier(random_state=0)
knn = KNeighborsClassifier()
lrc = LogisticRegression()
dtc = DecisionTreeClassifier()
ada = AdaBoostClassifier()
gdb = GradientBoostingClassifier()

# %%
#fit models
rfc.fit(X_train, y_train)
knn.fit(X_train, y_train)
lrc.fit(X_train, y_train)
dtc.fit(X_train, y_train)
ada.fit(X_train, y_train)
gdb.fit(X_train, y_train)
# Out:
# c:\Users\ndemb\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\ndemb\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# GradientBoostingClassifier()

# %%
#prediction
rfc_pred = rfc.predict(X_test)
knn_pred = rfc.predict(X_test)
lrc_pred = lrc.predict(X_test)
dtc_pred = dtc.predict(X_test)
ada_pred = ada.predict(X_test)
gdb_pred = gdb.predict(X_test)

# %%
# precision = precision_score(y_test, knn_pred)
# f1 = f1_score(y_test, knn_pred)
# recall = recall_score(y_test, knn_pred)

# print(f'Precision: {precision}')
# print(f'F1_score: {f1}')
# print(f'Recall_score: {recall}')

#Evaluation

print("\nRandom Forest evaluation")
accuracy = accuracy_score(y_test, rfc_pred)
print(f'Accuracy: {accuracy}')

print("\nKNeighbors evaluation")
accuracy = accuracy_score(y_test, knn_pred)
print(f'Accuracy: {accuracy}')

print("\nLogistic Regression evaluation")
accuracy = accuracy_score(y_test, lrc_pred)
print(f'Accuracy: {accuracy}')

print("\nDecisionTree Classifier evaluation")
accuracy = accuracy_score(y_test, dtc_pred)
print(f'Accuracy: {accuracy}')

print("\nAdaBoost Classifier evaluation")
accuracy = accuracy_score(y_test, ada_pred)
print(f'Accuracy: {accuracy}')

print("\nGradientBoost Classifier evaluation")
accuracy = accuracy_score(y_test, gdb_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Random Forest evaluation
# Accuracy: 0.7709016721337707
#
# KNeighbors evaluation
# Accuracy: 0.7709016721337707
#
# Logistic Regression evaluation
# Accuracy: 0.5259220737659013
#
# DecisionTree Classifier evaluation
# Accuracy: 0.7028562284982799
#
# AdaBoost Classifier evaluation
# Accuracy: 0.6391711336906952
#
# GradientBoost Classifier evaluation
# Accuracy: 0.6784142731418513

# %%
#Save the model
joblib.dump(rfc, 'trained_score_model_rfc.pkl')
joblib.dump(knn, 'trained_score_model_knn.pkl')
# Out:
# ['trained_score_model_knn.pkl']
